# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajshahil572/advance-Python/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# slicing
#[starting point : ending_point : steps] n+1
str = "kunal bhai"
print(str[9:0:-3])
print(str[8:0:-2])
# Out:
# iba
# abln

# %%
#condition
#if else
#age = 20
if age >18:
  print("you can vote")
else:
  print("bade hokar karna ")


#if elif else
int=input("inter your age")
if age <=12:
  print("child")
elif age <=19:
  print("teen")
elif age <=35:
  print("young Adult")
else:
 print("adult")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-504566007.py in <cell line: 0>()
#       2 #if else
#       3 #age = 20
# ----> 4 if age >18:
#       5   print("you can vote")
#       6 else:
#
# NameError: name 'age' is not defined

# %%
mark =int(input("inter your mark = "))
if mark >=90:
  print("grade A")
elif mark >=80 and mark <90:
    print("grade B")
elif mark >=70 and mark <80:
      print("grade C")
elif mark >=60 and mark <70:
        print("grade D")
elif mark >=45 and mark <60:
          print("grade E")
else:
            print("fail")

# %% [markdown]
# string and list in python are similar but string are immutable and list are mutable you can acsess the string but in list you can acess or change it also

# %%
#list
#student = ["aman", 88.5, 45, "shahil"]
#print("student")


#mutation
#student = ["aman", 88.5, 45, "shahil"]
#student[1] ="khushi" # Corrected 'Student' to 'student'
#print(student)

list = [55,96,36,65,59]
list.sort()
print(list)

list.reverse()
print(list)

# %%
list = ["aman","khushi","abhishek","shahil"]
list.append("aman")
print("list")

list = [55,56,57,58,59]
list.insert(2,"100")
print(list)

list = ["aman", "khushi", "abhishek", "shahil"]
list.remove("khushi")
print(list)

list = ["aman", "khushi", "abhishek", "shahil"]
list.pop(1)
print(list)

# %%
favorite_movies = []

print("Please enter the names of your four favorite movies:")

movie_1 = input("Enter movie #1: ")
movie_2 = input("Enter movie #2: ")
movie_3 = input("Enter movie #3: ")
movie_4 = input("Enter movie #4: ")

favorite_movies.extend([movie_1, movie_2, movie_3, movie_4])

print(favorite_movies)

# %%
list = (1,2,3,4,5)
if list == list[::-1]:
     print("The list is palindrome")
else:

      print("The list is not palindrome")

# %%
# tuples
tup = (85,45,63,75)
print(type(tup))
print(tup[1])

# %%
tup = (55)
print(type(tup))

tup = ("55")
print(type(tup))

a = 55,65
print(type(a))

# %%
# tuple method

tup = (5,9,6,4,3,4)
print(tup.index(3))

tup = (5,9,6,4,3,4)
print(tup.count(4))

# %% [markdown]
# wap to ask the user to inter name of there four fav moive and store them in a list

# %%
# dictionaries
dict = {"name : kunal", "age : 20"}
print(dict)

# %%
info = {
    "name" : "aman",
    "roll" : 45,
    "subject" :["ml","python","advance"],
    "topic" :["set", "dict"],
    "age" : 26
}
print(info)
print(info["name"])
print(info["roll"])
print(info["subject"])
print(info["topic"])

# %%
# nested
student = {
    "name" : "kunal",
    "age" : 20,
    "subject" : { "physics":98,
                 "chemistry":99,
                 }
}
print(student)
print(["name"])
print(student["age"])
print(student["subject"]["physics"])

# %%
info = {
    "name" : "aman",
    "roll" : 45,
    "subject" :["ml","python","advance"],
    "topic" :["set", "dict"],
    "age" : 26
}
print(info.keys())
print(info.values())
print(info.items())
print(info.get("name"))

# %%
my_set_variable = {"shahil","raj",45,43,12}
print(my_set_variable)

# %% [markdown]
# Unordered collection (order fix nahi hota)
#
# Unique elements only (duplicates allowed nahi)
#
# Mutable (add/remove kar sakte ho)

# %%
a = set()
print(type(a))

# %%
#set method
a = set()
a.add(55)
print(a)

a = {54,25,69,85,75}
a.add(55)
print(a)

# %%
#set method
a = {54,25,69,855,75}
a.remove(25)
print(a)

# %%
#set method
a = {54,25,69,855,75}
a.clear()
print(a)

# %%
#set method
a = {54,25,69,85,75}
a.pop()
print(a)

# %%
#set method
a = {54,25,69,85,75}
a.union()
print(a)

# %%
#set method
a = {54,25,69,85,75}
a.intersection()
print(a)

# %%
# loops
# while
# for

i = 1
while i <= 20:
  print("kunal",i)
  i = i+1

# %%
i = 1
while i<=20:
     print(i)
     i+=1

# %%
i = 20
while i>=1:
     print(i)
     i-=1

# %%
num = [1, 5, 7, 4, 2, 6, 5]

i = 0
while i < len(num):
    print(num[i])
    i += 1

# %%
num = (44, 25, 96, 36, 15, 75)
x = 36
i = 0

while i < len(num):
    if num[i] == x:
        print("found at idx", i)
        break
    else:
        print("not found")
    i += 1
    print("end")

# %%
# continue
i = 0
while i<=10:
  if(i==5):
    i+=1
    continue
  print(i)
  i+=1

# %%
i = 0
while i <= 10:

    if i % 2 == 0:
        i+=1
        continue
    print(i)
    i+=1

# %%
# for loop
a = ["aman","kunal","ally","akash"]
for i in a:
  print(i)

# %%
name = "kunal bhai"
for i in name:
  print(i)
else:

  print("end")

# %%
name = "kunal bhai"
for i in name:
  if(i=="l"):
      print(i,"l found,")
      break
  print(i)
else:
  print("end")
# Out:
# k
# u
# n
# a
# l l found,

# %%
num = (12,34,45,56,67,78,)
x = 56
idx = 0
for i in num:
  if(i==x):
    print("number found at idx", idx)
    idx+=1
# Out:
# number found at idx 0

# %%
# range
seq = range(1)
for i in seq:
  for i in seq:
   print(i)
# Out:
# 0

# %%
for i in range(0,10,2):
   print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(5, -1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# function
#def fun_name(parameters1,perameters2)
#  somework
# return

def sum(a,b):
  sum = a+b
  print(sum)
  return sum
sum(5,6)
# Out:
# 11
# 11

# %%
def sum(a, b):
    sum = a + b
    print(sum)
    return sum

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

sum(a, b)
# Out:
# Enter first number: 3
# Enter second number: 1
# 4
# 4

# %%
def avg(a, b, c):
    result = (a + b + c) / 3
    return result
print(avg(3, 6, 9))
# Out:
# 6.0

# %%
def prod(a=5, b=10):
    return a * b

print(prod(10))
# Out:
# 100

# %%
def print_length():
    city = ["delhi", "dehradun", "bettiah", "india"]
    heros = ["batman", "ironman", "saktiman"]

    print("Length of city list =", len(city))
    print("Length of heros list =", len(heros))

print_length()
# Out:
# Length of city list = 4
# Length of heros list = 3

# %%
def inr_to_usd(inr, rate=88):
    usd = inr / rate
    return usd

amount = float(input("Enter amount in INR: "))
result = inr_to_usd(amount)

print("USD =", round(result, 2))
# Out:
# Enter amount in INR: 100
# USD = 1.14

# %%
def my_function():
  pass

# %%
for i in range(10):
  if i == 5:
    pass
  else:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
# oops
class students:
  name = "kunal"

s1 = student()
print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-140847905.py in <cell line: 0>()
#       2   name = "kunal"
#       3
# ----> 4 s1 = student()
#       5 print(s1.name)
#
# NameError: name 'student' is not defined

# %%
class car:
  colour = "black"
  brand = "tata"

c1 = car()
print(c1.brand,c1.colour)
print(c1.colour)
# Out:
# tata black
# black

# %%
# class student:
# def_init_():

class student :
  def __init__(self,name,age,c_grade):
    self.name = name
    self.a = age
    self.grade = c_grade

s1 = student("kunal","24","A")
print(s1.name,s1.a,s1.grade)
# Out:
# kunal 24 A

# %%
class Student:
    def __init__(self, f_name, employee_id, salary,placement):
        self.name = f_name
        self.emp_id = employee_id
        self.salary = salary
        self.p = placement

s1 = Student("kunal", "202304029", "25k","yes")
print(s1.name, s1.emp_id, s1.salary,s1.p)
s1.name = "aman"
print(s1.name)
print(s1.name, s1.emp_id, s1.salary,s1.p)
# Out:
# kunal 202304029 25k yes
# aman
# aman 202304029 25k yes
