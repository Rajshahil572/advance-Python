# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajshahil572/advance-Python/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# slicing
#[starting point : ending_point : steps] n+1
str = "kunal bhai"
print(str[9:0:-3])
print(str[8:0:-2])
# Out:
# iba
# abln

# %%
#condition
#if else
#age = 20
if age >18:
  print("you can vote")
else:
  print("bade hokar karna ")


#if elif else
int=input("inter your age")
if age <=12:
  print("child")
elif age <=19:
  print("teen")
elif age <=35:
  print("young Adult")
else:
 print("adult")
# Out:
# you can vote
# inter your age11
# child

# %%
mark =int(input("inter your mark = "))
if mark >=90:
  print("grade A")
elif mark >=80 and mark <90:
    print("grade B")
elif mark >=70 and mark <80:
      print("grade C")
elif mark >=60 and mark <70:
        print("grade D")
elif mark >=45 and mark <60:
          print("grade E")
else:
            print("fail")
# Out:
# inter your mark = 58
# grade E

# %% [markdown]
# write a program to input the value if the value greater than 5 then print
# wap to check weather a no. is divisable by 7 or not
# tkinter
# wap to display hello if a no. enter by the user is a multiple of 5 otherwise print bye

# %% [markdown]
# string and list in python are similar but string are immutable and list are mutable you can acsess the string but in list you can acess or change it also

# %%
#list
#student = ["aman", 88.5, 45, "shahil"]
#print("student")


#mutation
#student = ["aman", 88.5, 45, "shahil"]
#student[1] ="khushi" # Corrected 'Student' to 'student'
#print(student)

list = [55,96,36,65,59]
list.sort()
print(list)

list.reverse()
print(list)
# Out:
# [96, 65, 59, 55, 36]
# [36, 55, 59, 65, 96]

# %%
list = ["aman","khushi","abhishek","shahil"]
list.append("aman")
print("list")

list = [55,56,57,58,59]
list.insert(2,"100")
print(list)

list = ["aman", "khushi", "abhishek", "shahil"]
list.remove("khushi")
print(list)

list = ["aman", "khushi", "abhishek", "shahil"]
list.pop(1)
print(list)
# Out:
# list
# [55, 56, '100', 57, 58, 59]
# ['aman', 'abhishek', 'shahil']
# ['aman', 'abhishek', 'shahil']
